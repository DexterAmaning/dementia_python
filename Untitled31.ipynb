# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
dementia_df = pd.read_csv("dementia.csv")
dementia_df
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80
# ..         ...            ...          ...    ...       ...  ..  ...  ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# ...

# %%
dementia_df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
dementia_df.tail()
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 368    16  1.0  28.0  0.5  1693  0.694  1.037
# 369    16  1.0  26.0  0.5  1688  0.675  1.040
# 370    13  2.0  30.0  0.0  1319  0.801  1.331
# 371    13  2.0  30.0  0.0  1327  0.796  1.323
# 372    13  2.0  30.0  0.0  1333  0.801  1.317

# %%
dementia_df.plot(kind ="bar", figsize =(20,10))
# Out:
# <Axes: >

# %%
dementia_df.info
# Out:
# <bound method DataFrame.info of     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80
# ..         ...            ...          ...    ...       ...  ..  ...  ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# ...

# %%
dementia_df.describe()
# Out:
#             Visit     MR Delay         Age        EDUC         SES  \
# count  373.000000   373.000000  373.000000  373.000000  354.000000
# mean     1.882038   595.104558   77.013405   14.597855    2.460452
# std      0.922843   635.485118    7.640957    2.876339    1.134005
# min      1.000000     0.000000   60.000000    6.000000    1.000000
# 25%      1.000000     0.000000   71.000000   12.000000    2.000000
# 50%      2.000000   552.000000   77.000000   15.000000    2.000000
# 75%      2.000000   873.000000   82.000000   16.000000    3.000000
# max      5.000000  2639.000000   98.000000   23.000000    5.000000
#
#              MMSE         CDR         eTIV        nWBV         ASF
# count  371.000000  373.000000   373.000000  373.000000  373.000000
# mean    27.342318    0.290885  1488.128686    0.729568    1.195461
# std      3.683244    0.374557   176.139286    0.037135    0.138092
# min      4.000000    0.000000  1106.000000    0.644000    0.876000
# ...

# %%
dementia_df.mean
# Out:
# <bound method DataFrame.mean of     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80
# ..         ...            ...          ...    ...       ...  ..  ...  ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# ...

# %%
dementia_df ["Group"].unique()
# Out:
# array(['Nondemented', 'Demented', 'Converted'], dtype=object)

# %%
dementia_df.shape
# Out:
# (373, 15)

# %%
dementia_df.isnull().sum()
# Out:
# Subject ID     0
# MRI ID         0
# Group          0
# Visit          0
# MR Delay       0
# M/F            0
# Hand           0
# Age            0
# EDUC           0
# SES           19
# MMSE           2
# CDR            0
# eTIV           0
# nWBV           0
# ASF            0
# dtype: int64

# %%
dementia_df = dementia_df.fillna("N/A")

# %%
dementia_df.isnull().sum()
# Out:
# Subject ID    0
# MRI ID        0
# Group         0
# Visit         0
# MR Delay      0
# M/F           0
# Hand          0
# Age           0
# EDUC          0
# SES           0
# MMSE          0
# CDR           0
# eTIV          0
# nWBV          0
# ASF           0
# dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.heatmap(dementia_df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values in Dataset")
plt.show()

# %%
dementia_df.columns
# Out:
# Index(['Subject ID', 'MRI ID', 'Group', 'Visit', 'MR Delay', 'M/F', 'Hand',
#        'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV', 'ASF'],
#       dtype='object')

# %%
# Replace missing numeric values with "N/A" (or 0 if you want to keep numeric type)
dementia_df[['SES', 'MMSE']] = dementia_df[['SES', 'MMSE']].fillna("N/A")

# %%
dementia_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Subject ID  373 non-null    object
#  1   MRI ID      373 non-null    object
#  2   Group       373 non-null    object
#  3   Visit       373 non-null    int64
#  4   MR Delay    373 non-null    int64
#  5   M/F         373 non-null    object
#  6   Hand        373 non-null    object
#  7   Age         373 non-null    int64
#  8   EDUC        373 non-null    int64
#  9   SES         373 non-null    object
#  10  MMSE        373 non-null    object
#  11  CDR         373 non-null    float64
#  12  eTIV        373 non-null    int64
#  13  nWBV        373 non-null    float64
#  14  ASF         373 non-null    float64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 43.8+ KB

# %%
# Example in pandas
df = df.drop(columns=['MR Delay'])  # or ['Visit']

# %%
dementia_df
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80
# ..         ...            ...          ...    ...       ...  ..  ...  ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# ...

# %%
dementia_df["Group"].unique()
# Out:
# array(['Nondemented', 'Demented', 'Converted'], dtype=object)

# %%
dementia_df
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80
# ..         ...            ...          ...    ...       ...  ..  ...  ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# ...

# %%
X = dementia_df.drop("Group", axis=1)
Y = dementia_df["Group"]

# %%
X
# Out:
#     Subject ID         MRI ID  Visit  MR Delay M/F Hand  Age  EDUC  SES  MMSE  \
# 0    OAS2_0001  OAS2_0001_MR1      1         0   M    R   87    14  2.0  27.0
# 1    OAS2_0001  OAS2_0001_MR2      2       457   M    R   88    14  2.0  30.0
# 2    OAS2_0002  OAS2_0002_MR1      1         0   M    R   75    12  NaN  23.0
# 3    OAS2_0002  OAS2_0002_MR2      2       560   M    R   76    12  NaN  28.0
# 4    OAS2_0002  OAS2_0002_MR3      3      1895   M    R   80    12  NaN  22.0
# ..         ...            ...    ...       ...  ..  ...  ...   ...  ...   ...
# 368  OAS2_0185  OAS2_0185_MR2      2       842   M    R   82    16  1.0  28.0
# 369  OAS2_0185  OAS2_0185_MR3      3      2297   M    R   86    16  1.0  26.0
# 370  OAS2_0186  OAS2_0186_MR1      1         0   F    R   61    13  2.0  30.0
# 371  OAS2_0186  OAS2_0186_MR2      2       763   F    R   63    13  2.0  30.0
# 372  OAS2_0186  OAS2_0186_MR3      3      1608   F    R   65    13  2.0  30.0
#
#      CDR  eTIV   nWBV    ASF
# ...

# %%
Y
# Out:
# 0      Nondemented
# 1      Nondemented
# 2         Demented
# 3         Demented
# 4         Demented
#           ...
# 368       Demented
# 369       Demented
# 370    Nondemented
# 371    Nondemented
# 372    Nondemented
# Name: Group, Length: 373, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
Y_encoded = le.fit_transform(Y)
print(Y_encoded[:10])
# Out:
# [2 2 1 1 1 2 2 2 2 2]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# 1. Features and target
X = dementia_df.drop("Group", axis=1)
Y = dementia_df["Group"]

# 2. Encode Y (convert labels to numbers)
le = LabelEncoder()
Y_encoded = le.fit_transform(Y)

# 3. Split into train and test sets (default 75% train, 25% test)
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y_encoded, test_size=0.25, random_state=42, stratify=Y_encoded
)

# Check shapes
print("X_train:", X_train.shape)
print("X_test: ", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_test: ", Y_test.shape)
# Out:
# X_train: (279, 14)
# X_test:  (94, 14)
# Y_train: (279,)
# Y_test:  (94,)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Drop identifiers
X = dementia_df.drop(columns=["Group", "Subject ID", "MRI ID"])
y = dementia_df["Group"]

# Convert MMSE to numeric
X["MMSE"] = pd.to_numeric(X["MMSE"], errors='coerce')  # turns non-numeric to NaN

# Encode categorical columns
for col in ["M/F", "Hand", "SES"]:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])

# Impute missing values (if any)
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# Encode target
y_encoded = LabelEncoder().fit_transform(y)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_encoded, test_size=0.25, random_state=42, stratify=y_encoded
)

# Train SVM
svc_model = SVC(kernel='linear', C=1.0, random_state=42)
svc_model.fit(X_train, y_train)

# Predict & evaluate
y_pred = svc_model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9148936170212766
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.22      0.33         9
#            1       0.95      0.97      0.96        37
#            2       0.91      1.00      0.95        48
#
#     accuracy                           0.91        94
#    macro avg       0.84      0.73      0.75        94
# weighted avg       0.90      0.91      0.90        94
#
#
# Confusion Matrix:
#  [[ 2  2  5]
#  [ 1 36  0]
#  [ 0  0 48]]

# %%
svc_model = SVC(kernel='linear', C=1.0, class_weight='balanced', random_state=42)

# %%
svc_model = SVC(kernel='rbf', C=1.0, gamma='scale', class_weight='balanced', random_state=42)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C':[0.1,1,10], 'gamma':['scale','auto'], 'kernel':['rbf','linear']}
grid = GridSearchCV(SVC(class_weight='balanced'), param_grid, cv=5)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(class_weight='balanced'),
#              param_grid={'C': [0.1, 1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear']})

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE

# ----------------------------
# 1. Prepare features and target
# ----------------------------
X = dementia_df.drop(columns=["Group", "Subject ID", "MRI ID"])
y = dementia_df["Group"]

# Convert MMSE to numeric (coerce errors to NaN)
X["MMSE"] = pd.to_numeric(X["MMSE"], errors='coerce')

# Encode categorical columns
for col in ["M/F", "Hand", "SES"]:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])

# ----------------------------
# 2. Impute missing values
# ----------------------------
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# ----------------------------
# 3. Scale features
# ----------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# ----------------------------
# 4. Encode target
# ----------------------------
y_encoded = LabelEncoder().fit_transform(y)

# ----------------------------
# 5. Split dataset
# ----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_encoded, test_size=0.25, random_state=42, stratify=y_encoded
)

# ----------------------------
# 6. Handle class imbalance with SMOTE
# ----------------------------
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# ----------------------------
# 7. Hyperparameter tuning with GridSearchCV
# ----------------------------
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto'],
    'kernel': ['rbf']
}

grid = GridSearchCV(SVC(class_weight='balanced', random_state=42), 
                    param_grid, cv=5, scoring='f1_weighted', n_jobs=-1)
grid.fit(X_train_res, y_train_res)

best_model = grid.best_estimator_
print("Best hyperparameters:", grid.best_params_)

# ----------------------------
# 8. Predict & Evaluate
# ----------------------------
y_pred = best_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Best hyperparameters: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# Accuracy: 0.8936170212765957
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.22      0.29         9
#            1       0.95      0.95      0.95        37
#            2       0.90      0.98      0.94        48
#
#     accuracy                           0.89        94
#    macro avg       0.75      0.72      0.72        94
# weighted avg       0.87      0.89      0.88        94
#
#
# Confusion Matrix:
#  [[ 2  2  5]
#  [ 2 35  0]
#  [ 1  0 47]]
